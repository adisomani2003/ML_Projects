# %% [markdown]
# ## Notebook Imports and packages

# %%
import matplotlib.pyplot as plt
import numpy as np

from mpl_toolkits.mplot3d.axes3d import Axes3D
from matplotlib import cm # color map

from sympy import symbols, diff
from math import log

from sklearn.linear_model import LinearRegression as LR
from sklearn.metrics import mean_squared_error

# %matplotlib inline

# %% [markdown]
# # Example 1- A simple cost function
#
# ### $f(x)=x^2+x+1$

# %%
def f(x):
    return x**2+x+1

# %%
#Generating data

x_1= np.linspace(start=-3,stop=3,num=10000)

# %%
#Plot
plt.plot(x_1,f(x_1))
plt.show

#Just to make it look better
plt.xlim(-3,3)
plt.ylim(0,8)

plt.xlabel('X',fontsize=16)
plt.ylabel('f(X)',fontsize=16)
# Out:
# Text(0, 0.5, 'f(X)')

# %% [markdown]
# # Slope and derivatives

# %%
def df(x):
    return 2*x+1

# %%
#Changing size(measured in inches)
plt.figure(figsize=[15,5])

#1Chart- Cost Function
plt.subplot(1,2,1)
plt.plot(x_1,f(x_1),color='blue',linewidth=3)

#Just to make it look better
plt.xlim(-3,3)
plt.ylim(0,8)

plt.xlabel('X',fontsize=16)
plt.ylabel('f(X)',fontsize=16)
plt.title('Cost Function', fontsize=17)

#2Chart- Derivative

plt.subplot(1,2,2)
plt.title('Slope of Cost Function', fontsize=17)
plt.plot(x_1,df(x_1),color='skyblue',linewidth=5)
plt.xlim(-2,3)
plt.ylim(-3,6)

plt.xlabel('X',fontsize=16)
plt.ylabel('df(X)',fontsize=16)
#adding a grid to second graph to see where the intersection with 0 is
plt.grid()

plt.show()

# %%
#same graphs but up down
#Changing size(measured in inches)
plt.figure(figsize=[5,15])

#1Chart- Cost Function
plt.subplot(2,1,1)
plt.plot(x_1,f(x_1),color='blue',linewidth=3)

#Just to make it look better
plt.xlim(-3,3)
plt.ylim(0,8)

plt.xlabel('X',fontsize=16)
plt.ylabel('f(X)',fontsize=16)
plt.title('Cost Function', fontsize=17)

#2Chart- Derivative

plt.subplot(2,1,2)
plt.title('Slope of Cost Function', fontsize=17)
plt.plot(x_1,df(x_1),color='skyblue',linewidth=5)
plt.xlim(-2,3)
plt.ylim(-3,6)

plt.xlabel('X',fontsize=16)
plt.ylabel('df(X)',fontsize=16)
#adding a grid to second graph to see where the intersection with 0 is
plt.grid()

plt.show()

# %% [markdown]
# # Python Loops and Gradient Decent

# %%
#for loop
for n in range(5):
    print('Hello World',n)
# Out:
# Hello World 0
# Hello World 1
# Hello World 2
# Hello World 3
# Hello World 4

# %%
#while loop
counter=0
while counter<7:
    print('Counting...',counter)
    counter=counter+1

print('Ready or not, here I come ;)')
# Out:
# Counting... 0
# Counting... 1
# Counting... 2
# Counting... 3
# Counting... 4
# Counting... 5
# Counting... 6
# Ready or not, here I come ;)

# %%
#Gradient descent

#3 things
#1-starting point
#learning rate
#temprory value

new_x=3
previous_x=0
step_multiplier=0.1
precision=0.000001

x_list=[new_x]
slope_list=[df(new_x)]

for n in range(500):
    previous_x=new_x
    gradient=df(previous_x)
    new_x=previous_x-step_multiplier*gradient
    
    step_size=abs(new_x-previous_x)
    
    x_list.append(new_x)
    slope_list.append(df(new_x))
    
    if step_size<precision:
        print('Loop ran this many times:', n)
        break
    
print('Local minimum occurs at:', new_x)
print('Slope or df(x) value at this point is:', df(new_x))
print('f(x) value or cost at this point is:', f(new_x))
# Out:
# Loop ran this many times: 61
# Local minimum occurs at: -0.4999965672099885
# Slope or df(x) value at this point is: 6.8655800230521535e-06
# f(x) value or cost at this point is: 0.750000000011784

# %%
#Superimposing the gradient descent algorithm on plot
plt.figure(figsize=[20,5])

#1Chart- Cost Function
plt.subplot(1,3,1)
plt.plot(x_1,f(x_1),color='blue',linewidth=3,alpha=0.8)

#Just to make it look better
plt.xlim(-3,3)
plt.ylim(0,8)

plt.xlabel('X',fontsize=16)
plt.ylabel('f(X)',fontsize=16)
plt.title('Cost Function', fontsize=17)

#the function f is not defined s.t. it can take a list as an input so we convert it to an array
values=np.array(x_list)
plt.scatter(x_list,f(values), color='red',s=100,alpha=.6)

#2Chart- Derivative

plt.subplot(1,3,2)
plt.title('Slope of Cost Function', fontsize=17)
plt.plot(x_1,df(x_1),color='skyblue',linewidth=5,alpha=0.8)
plt.xlim(-2,3)
plt.ylim(-3,6)

plt.xlabel('X',fontsize=16)
plt.ylabel('df(X)',fontsize=16)
#adding a grid to second graph to see where the intersection with 0 is
plt.grid()
plt.scatter(x_list,df(values),color='red',s=100,alpha=.6)


#adding a zoomed in plot
#3Chart- Derivative

plt.subplot(1,3,3)
plt.title('Gradient Descent(close up)', fontsize=17)
plt.plot(x_1,df(x_1),color='skyblue',linewidth=5,alpha=0.8)
plt.xlim(-0.55,-0.2)
plt.ylim(-0.3,0.8)


#adding a grid to second graph to see where the intersection with 0 is
plt.grid()
plt.scatter(x_list,df(values),color='red',s=300,alpha=.6)


plt.show()

# %% [markdown]
# # Example 2- Multiple Minima vs Initial Guess & Advanced functions
# ## $$g(x)=x^4-4x^2+5$$

# %%
#Making data
x_2=np.linspace(-2,2,1000)

# %%
def g(x):
    return x**4-4*x**2+5

# %%
def dg(x):
    return 4*x**3-8*x

# %%
#Changing size(measured in inches)
plt.figure(figsize=[15,5])

#1Chart- Cost Function
plt.subplot(1,2,1)
plt.plot(x_2,g(x_2),color='blue',linewidth=3)

#Just to make it look better
plt.xlim(-2,2)
plt.ylim(0.5,5.5)

plt.xlabel('X',fontsize=16)
plt.ylabel('g(X)',fontsize=16)
plt.title('Cost Function', fontsize=17)

#2Chart- Derivative

plt.subplot(1,2,2)
plt.title('Slope of Cost Function', fontsize=17)
plt.plot(x_2,dg(x_2),color='skyblue',linewidth=5)
plt.xlim(-2,2)
plt.ylim(-2,8)

plt.xlabel('X',fontsize=16)
plt.ylabel('df(X)',fontsize=16)
#adding a grid to second graph to see where the intersection with 0 is
plt.grid()

plt.show()

# %% [markdown]
# ## Gradient Descent as a python function

# %%
def gradient_descent(derivative_func, initial_guess, multiplier=0.02, precision=0.001, max_iter=1000):
#we have given multiplier and precision a default value, u can still overwrite them while calling the function

    new_x=initial_guess

    x_list=[new_x]
    slope_list=[derivative_func(new_x)]

    for n in range(max_iter):
        previous_x=new_x
        gradient=derivative_func(previous_x)
        new_x=previous_x-multiplier*gradient

        step_size=abs(new_x-previous_x)

        x_list.append(new_x)
        slope_list.append(derivative_func(new_x))

        if step_size<precision:
            break

    return new_x,x_list,slope_list

# %%
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess=-2)
print('Local min occurs at:', local_min)
print('Number of steps:', len(x_list))
# Out:
# Local min occurs at: -1.4159909120185952
# Number of steps: 63

# %%
#Calling gradient descent function
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess=-2)
plt.figure(figsize=[15,5])


#1Chart- Cost Function
plt.subplot(1,2,1)
plt.plot(x_2,g(x_2),color='blue',linewidth=3,alpha=0.8)

#Just to make it look better
plt.xlim(-3,3)
plt.ylim(0,8)

plt.xlabel('X',fontsize=16)
plt.ylabel('g(X)',fontsize=16)
plt.title('Cost Function', fontsize=17)
plt.scatter(list_x,g(np.array(list_x)),color='r',s=100,alpha=0.6)

#2Chart- Derivative
plt.subplot(1,2,2)
plt.title('Slope of Cost Function', fontsize=17)
plt.plot(x_2,dg(x_2),color='skyblue',linewidth=5,alpha=0.8)
plt.xlim(-2,3)
plt.ylim(-3,6)

plt.xlabel('X',fontsize=16)
plt.ylabel('dg(X)',fontsize=16)
plt.scatter(list_x,deriv_list,color='r',s=100,alpha=0.6)
#adding a grid to second graph to see where the intersection with 0 is
plt.grid()

plt.show()

# %% [markdown]
# # Example 3-Divergence, Overflow and Python Tuples
#
# ## $$h(x)=x^5-2x^4+2$$

# %%
# Make data
x_3 = np.linspace(start=-2.5, stop=2.5, num=1000)

def h(x):
    return x**5 - 2*x**4 + 2

def dh(x):
    return 5*x**4 - 8*x**3

# %%
#Calling gradient descent function
local_min, list_x, deriv_list = gradient_descent(derivative_func=dh, initial_guess=-0.2, max_iter=71)
plt.figure(figsize=[15,5])


#1Chart- Cost Function
plt.subplot(1,2,1)
plt.plot(x_3,h(x_3),color='blue',linewidth=3,alpha=0.8)

#Just to make it look better
plt.xlim(-1.2,2.5)
plt.ylim(-1,4)

plt.xlabel('X',fontsize=16)
plt.ylabel('h(X)',fontsize=16)
plt.title('Cost Function', fontsize=17)
plt.scatter(list_x,h(np.array(list_x)),color='r',s=100,alpha=0.6)

#2Chart- Derivative
plt.subplot(1,2,2)
plt.title('Slope of Cost Function', fontsize=17)
plt.plot(x_3,dh(x_3),color='skyblue',linewidth=5,alpha=0.8)
plt.xlim(-1,2)
plt.ylim(-4,5)

plt.xlabel('X',fontsize=16)
plt.ylabel('dh(X)',fontsize=16)
plt.scatter(list_x,deriv_list,color='r',s=100,alpha=0.6)
#adding a grid to second graph to see where the intersection with 0 is
plt.grid()

plt.show()

print('Local minimum occurs at', local_min)
print('Cost at minimum is', h(local_min))
print('Number of steps',len(list_x))
# Out:
# Local minimum occurs at -1.8398461123332792e+24
# Cost at minimum is -2.1081790694225687e+121
# Number of steps 72

# %%
type(local_min)
# Out:
# float

# %%
import sys
#help(sys)
sys.version
sys.float_info.min
# Out:
# 2.2250738585072014e-308

# %% [markdown]
# ## Python Tuples

# %%
#creating a tuple-tuple packing
breakfast='bacon','eggs','avocado'
unlucky_numbers=13,4,9,26,420

#How to access values in tuples
print('I love', breakfast[1])
print('My hotel has '+str(unlucky_numbers[2])+' floors')

#Tuples are hetrogrnous unlike lists, they can store different types of data simultaneously
not_my_address=1,'hi',5668.2,'yo'

#Tuple item assignment cant change
#breakfast[0]=sausage- this wont work

#Sequence unpacking
main,side,greens=breakfast
print('Main course is', main)
data_tuple= gradient_descent(derivative_func=dh, initial_guess=0.2)
print('Local min is', data_tuple[0])
print('Cost at the last x value is', h(data_tuple[0]))
print('Number of steps is', len(data_tuple[1]))
# Out:
# I love eggs
# My hotel has 9 floors
# Main course is bacon
# Local min is 1.5989534547394717
# Cost at the last x value is -0.6214287992331258
# Number of steps is 117

# %%
#Calling gradient descent function
n=100
low_gamma = gradient_descent(derivative_func=dg, initial_guess=3,multiplier=0.0005,precision=0.0001, max_iter=n)
plt.figure(figsize=[20,10])

mid_gamma = gradient_descent(derivative_func=dg, initial_guess=3,multiplier=0.001,precision=0.0001, max_iter=n)

high_gamma = gradient_descent(derivative_func=dg, initial_guess=3,multiplier=0.002,precision=0.0001, max_iter=n)

insane_gamma = gradient_descent(derivative_func=dg, initial_guess= 1.9,
                                                multiplier=0.25, precision=0.0001, max_iter=n)


#Just to make it look better
plt.xlim(0,n)
plt.ylim(0,50)

plt.xlabel('Nr of interactions',fontsize=16)
plt.ylabel('Cost',fontsize=16)
plt.title('Effect of learning rate', fontsize=17)

# Values for our charts
# 1) Y Axis Data: convert the lists to numpy arrays
low_values = np.array(low_gamma[1])

# 2) X Axis Data: create a list from 0 to n+1
iteration_list = list(range(0, n+1))
# Plotting low learning rate
plt.plot(iteration_list, g(low_values), color='lightgreen', linewidth=5)
plt.scatter(iteration_list,g(low_values),color='lightgreen', s=80)



mid_values=np.array(mid_gamma[1])
plt.plot(iteration_list, g(mid_values), color='steelblue', linewidth=5)
plt.scatter(iteration_list,g(mid_values),color='steelblue', s=80)


high_values=np.array(high_gamma[1])
plt.plot(iteration_list, g(high_values), color='hotpink', linewidth=5)
plt.scatter(iteration_list,g(high_values),color='hotpink', s=80)

insane_values=np.array(insane_gamma[1])
plt.plot(iteration_list, g(insane_values), color='red', linewidth=5)

plt.scatter(iteration_list,g(insane_values),color='red', s=80)

# %% [markdown]
# # Example 4-Data Viz with 3D Charts
#
# ## Minimise$$f(x,y)=\frac{1}{3^{-x^2-y^2}+1}$$

# %%
def f(x,y):
    r=3**(-x**2-y**2)
    return 1/(r+1)

# %%
#generating data
x_4=np.linspace(-2,2,200)
y_4=np.linspace(-2,2,200)


print('Shape of X array', x_4.shape)
#keep in mind this is a vector, shape is (200,) which means 200 rows

x_4,y_4=np.meshgrid(x_4,y_4)

print('Shape of X array after the meshgrid', x_4.shape)
#this function returns a 2d-matrix from a 1-d vector
# Out:
# Shape of X array (200,)
# Shape of X array after the meshgrid (200, 200)

# %%
# Generating 3D Plot
fig = plt.figure(figsize=[16, 12])

ax = fig.gca(projection='3d')
#gca is a function known as get current axes


#This wont run straightaway as this function requires a 2d array as the input thats why we used the meshgrid

ax.plot_surface(x_4,y_4,f(x_4,y_4),cmap=cm.cool, alpha=0.4)


#adding labels
ax.set_xlabel('X', fontsize=20)
ax.set_ylabel('Y', fontsize=20)
ax.set_zlabel('f(x,y)-Cost', fontsize=20)

plt.show()

# %% [markdown]
# ## Partial derivatives and symbolic computation
#
# ## $$\frac{\partial f}{\partial x} = \frac{2x \ln(3) \cdot 3^{-x^2-y^2}}{\left (3^{-x^2-y^2}+1 \right)^2}$$
# ## $$\frac{\partial f}{\partial y} = \frac{2y \ln(3) \cdot 3^{-x^2-y^2}}{\left (3^{-x^2-y^2}+1 \right)^2}$$

# %%
a, b = symbols('x,y')
print('Our cost function f(x,y) is: ',f(a,b))

# Partial Differentation wrt a certain variable
print('Partial derivative wrt x is: ', diff(f(a,b), a))

#evaluating value of function at given inputs
print('Value of f(x,y) at x=1.8,y=1.0 is: ',f(a,b).evalf(subs={a:1.8, b:1.0})) #python dichtionary

#evaluating value of partial derivative at given input
print('Value of partial derivative wrt x: ', diff(f(a, b), a).evalf(subs={a:1.8, b:1.0}))
# Out:
# Our cost function f(x,y) is:  1/(3**(-x**2 - y**2) + 1)
# Partial derivative wrt x is:  2*3**(-x**2 - y**2)*x*log(3)/(3**(-x**2 - y**2) + 1)**2
# Value of f(x,y) at x=1.8,y=1.0 is:  0.990604794032582
# Value of partial derivative wrt x:  0.0368089716197505

# %% [markdown]
# ## Batch Gradient Descent with SymPy

# %%
#setup
multiplier=0.1
max_iter=1000

#2 or more values- best is to work with a numpy array

params=np.array([1.8,1.0]) #initial guess

for n in range (max_iter):
    gradient_x = diff(f(a,b),a).evalf(subs={a:params[0], b:params[1]})
    gradient_y = diff(f(a,b),b).evalf(subs={a:params[0], b:params[1]})
    gradients=np.array([gradient_x, gradient_y])
    params=params - multiplier * gradients
    

print('Values in gradient array', gradients)
print('Minimum occurs at x value of: ', params[0])
print('Minimum occurs at y value of: ', params[1])
print('The cost is: ', f(params[0], params[1]))
# Out:
# Values in gradient array [1.08410585157738e-23 6.02281028654100e-24]
# Minimum occurs at x value of:  1.86518075868510e-23
# Minimum occurs at y value of:  1.03621153260284e-23
# The cost is:  0.500000000000000

# %%
#think how to optimize this

# %%
# Partial derivative functions

#Needed to import math library for log function, if nothing is specefied base e is taken

def fpx(x, y):
    r = 3**(-x**2 - y**2)
    return 2*x*log(3)*r / (r + 1)**2

def fpy(x, y):
    r = 3**(-x**2 - y**2)
    return 2*y*log(3)*r / (r + 1)**2

# %%
type(log)
# Out:
# builtin_function_or_method

# %%
#setup
multiplier=0.1
max_iter=1000

#2 or more values- best is to work with a numpy array

params=np.array([1.8,1.0]) #initial guess


#this is much faster then sympy cause in sympy each time the derivative is calculated then the value is plugged in
#hence the time is increased significantly

for n in range (max_iter):
    gradient_x = fpx(params[0], params[1])
    gradient_y = fpy(params[0], params[1])
    gradients=np.array([gradient_x, gradient_y])
    params=params - multiplier * gradients
    

print('Values in gradient array', gradients)
print('Minimum occurs at x value of: ', params[0])
print('Minimum occurs at y value of: ', params[1])
print('The cost is: ', f(params[0], params[1]))
# Out:
# Values in gradient array [1.08410585e-23 6.02281029e-24]
# Minimum occurs at x value of:  1.865180758685096e-23
# Minimum occurs at y value of:  1.0362115326028303e-23
# The cost is:  0.5

# %% [markdown]
# ## Graphing 3D  Descent and Adv NumPy Arrays

# %%
#setup
multiplier=0.1
max_iter=1000
values_array=params.reshape(1,2) #this transforms arrays, now the array has 1 row and 2 columns
print(values_array.shape)
#2 or more values- best is to work with a numpy array

params=np.array([1.8,1.0]) #initial guess

for n in range (max_iter):
    gradient_x = fpx(params[0], params[1])
    gradient_y = fpy(params[0], params[1])
    gradients=np.array([gradient_x, gradient_y])
    params=params - multiplier * gradients
    #values_array = np.append(values_array, params.reshape(1,2), axis=0)
    values_array=np.concatenate((values_array, params.reshape(1,2)), axis=0)

#Concatenate works the same way as the line commented out above it just that the input of arrays is given in as tuples

print('Values in gradient array', gradients)
print('Minimum occurs at x value of: ', params[0])
print('Minimum occurs at y value of: ', params[1])
print('The cost is: ', f(params[0], params[1]))
# Out:
# (1, 2)
# Values in gradient array [1.08410585e-23 6.02281029e-24]
# Minimum occurs at x value of:  1.865180758685096e-23
# Minimum occurs at y value of:  1.0362115326028303e-23
# The cost is:  0.5

# %%
values_array
# Out:
# array([[1.86518076e-23, 1.03621153e-23],
#        [1.79631910e+00, 9.97955057e-01],
#        [1.79257650e+00, 9.95875836e-01],
#        ...,
#        [2.08830312e-23, 1.16016840e-23],
#        [1.97359134e-23, 1.09643964e-23],
#        [1.86518076e-23, 1.03621153e-23]])

# %%
# Generating 3D Plot
fig = plt.figure(figsize=[16, 12])

ax = fig.gca(projection='3d')
#gca is a function known as get current axes


#This wont run straightaway as this function requires a 2d array as the input thats why we used the meshgrid

ax.plot_surface(x_4,y_4,f(x_4,y_4),cmap=cm.coolwarm, alpha=0.4)


#adding labels
ax.set_xlabel('X', fontsize=20)
ax.set_ylabel('Y', fontsize=20)
ax.set_zlabel('f(x,y)-Cost', fontsize=20)

ax.scatter(values_array[:,0], values_array[:,1],f(values_array[:,0], values_array[:,1]),s=50,  color='r')

plt.show()

# %%
#Advanced Numpy Array Practice
    
kirk = np.array([['Captian', 'Guitar']])
print(kirk.shape)

hs_band = np.array([['Black Thought', 'MC'], ['Questlove', 'Drums']])

print(hs_band.shape)

print('hs_band',hs_band[1][0])# This [0][1] is how we get a particular value

the_roots = np.append(arr=hs_band,values=kirk, axis=0)
#Do Shift+Tab and read about the code above again
print(the_roots)

print('Printing Nicknames....', the_roots[:,0])
# : is used to print the first complete column

the_roots = np.append(arr = the_roots, values = [['Malik B', 'MC']], axis=0)
print('Printing band roles....', the_roots[:, 1])
# Out:
# (1, 2)
# (2, 2)
# hs_band Questlove
# [['Black Thought' 'MC']
#  ['Questlove' 'Drums']
#  ['Captian' 'Guitar']]
# Printing Nicknames.... ['Black Thought' 'Questlove' 'Captian']
# Printing band roles.... ['MC' 'Drums' 'Guitar' 'MC']

# %% [markdown]
# # Example 5 - Working with Data & a Real Cost Function
#
# ## Mean Squared Error: a cost function for regression problems
#
# ### $$RSS = \sum_{i=1}^n\big(y^{(i)}-h_\theta x^{(i)} \big)^2$$
#
# ### $$MSE = \frac{1}{n}\sum_{i=1}^n\big(y^{(i)}-h_\theta x^{(i)} \big)^2$$
#
# ### $$MSE = \frac{1}{n}\sum_{i=1}^n\big(y-\hat{y} \big)^2$$

# %%
#Make Sample Data

x_5 = np.array([[0.1, 1.2, 2.4, 3.2, 4.1, 5.7, 6.5]]).transpose()
y_5 = np.array([1.7, 2.4, 3.5, 3.0, 6.1, 9.4, 8.2]).reshape(7,1)

#Same thing achieved in above 2 lines but in different ways

print('Shape of x_5 array: ', x_5.shape)
print('Shape of y_5 array: ', y_5.shape)
# Out:
# Shape of x_5 array:  (7, 1)
# Shape of y_5 array:  (7, 1)

# %%
#Quick Linear Regression
regr=LR()

regr.fit(x_5,y_5)
#this fit method requires a 2 dimensional input

print('Theta 0: ', regr.intercept_[0])
print('Theta 1: ', regr.coef_[0][0])
# Out:
# Theta 0:  0.8475351486029536
# Theta 1:  1.2227264637835915

# %%
plt.scatter(x_5, y_5, s=50)
plt.plot(x_5, regr.predict(x_5), color='orange', linewidth=3)

plt.xlabel('X values')
plt.ylabel('Y values')
plt.show()

# %%
# y_hat = theta0 + theta1*x(y=c+mx)
y_hat = 0.8475351486029536 + 1.2227264637835915*x_5

print('Estimated values of Y are \n', y_hat)

print('In comparison the actual Y values are \n', y_5)
# Out:
# Estimated values of Y are
#  [[0.96980779]
#  [2.31480691]
#  [3.78207866]
#  [4.76025983]
#  [5.86071365]
#  [7.81707599]
#  [8.79525716]]
# In comparison the actual Y values are
#  [[1.7]
#  [2.4]
#  [3.5]
#  [3. ]
#  [6.1]
#  [9.4]
#  [8.2]]

# %%
def mse(y,yhat):
    #mse_calc = 1/7 * sum((y - y_hat)**2)
    #mse_calc = (1/y.size) * sum((y - y_hat)**2)
    mse_calc = np.average((y-yhat)**2, axis=0)
    #We have to tell the average function what will it be averaging(rows or columns), that information is given using axis
    return mse_calc

# %%
print('Manually calculated MSE is', mse(y_5,y_hat))
print('MSE regression using mannual calc is', mean_squared_error(y_5,y_hat))
print('MSE regression is', mean_squared_error(y_5, regr.predict(x_5)))
# Out:
# Manually calculated MSE is [0.94796558]
# MSE regression using mannual calc is 0.9479655759794577
# MSE regression is 0.9479655759794577

# %% [markdown]
# ## 3D Plot for the MSE Cost Function
#
# ### Make data for thetas

# %%
nr_thetas=200
th_0 = np.linspace(-1,3,nr_thetas)
th_1 = np.linspace(-1,3,nr_thetas)

plot_t0, plot_t1 = np.meshgrid(th_0,th_1)
#Remember meshgrid works as tuples so the values are assigned by unwrapping

# %% [markdown]
# ### Calc MSE using nested for loops

# %%
plot_cost = np.zeros((nr_thetas,nr_thetas))

#zeroes function just creates 0 martix

for i in range(nr_thetas):
    for j in range (nr_thetas):
        #print(plot_t0[i][j])
        y_hat = plot_t0[i][j] + plot_t1[i][j]*x_5
        plot_cost[i][j] = mse(y_5, y_hat)

print('Shape of plot_t0', plot_t0.shape)
print('Shape of plot_t1', plot_t1.shape)
print('Shape of plot_cost', plot_cost.shape)
# Out:
# Shape of plot_t0 (200, 200)
# Shape of plot_t1 (200, 200)
# Shape of plot_cost (200, 200)

# %%
#Nested Loop practice
for i in range(3):
    for j in range (3):
        print(f'value of i is {i} and j is {j}')
        
        
#Using the curly braces we are able to tell python to not consider i and j as string
# Out:
# value of i is 0 and j is 0
# value of i is 0 and j is 1
# value of i is 0 and j is 2
# value of i is 1 and j is 0
# value of i is 1 and j is 1
# value of i is 1 and j is 2
# value of i is 2 and j is 0
# value of i is 2 and j is 1
# value of i is 2 and j is 2

# %%
# Plotting MSE
fig = plt.figure(figsize=[16, 12])
ax = fig.gca(projection='3d')

ax.set_xlabel('Theta 0', fontsize= 20)
ax.set_ylabel('Theta 1', fontsize= 20)
ax.set_zlabel('Cost - MSE', fontsize= 20)

ax.plot_surface(plot_t0, plot_t1, plot_cost, cmap=cm.hot)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print('Min value of plot_cost', plot_cost.min())

#Calculating the corresponding values of x and y where we get the minimum cost
ij_min = np.unravel_index(indices = plot_cost.argmin(), shape=plot_cost.shape)

print('Min occurs at ij= ', ij_min)
print('Min MSE fot Theta_0 at plot_t0[111][91] =', plot_t0[111][91])
print('Min MSE fot Theta_1 at plot_t1[111][91] =', plot_t1[111][91])
# Out:
# Min value of plot_cost 0.9483826526747164
# Min occurs at ij=  (111, 91)
# Min MSE fot Theta_0 at plot_t0[111][91] = 0.829145728643216
# Min MSE fot Theta_1 at plot_t1[111][91] = 1.2311557788944723

# %% [markdown]
# ## Partial Derivatives w.r.t $\theta_0$ and $\theta_1$
#
# ## $$\frac{\partial MSE}{\partial \theta_0} = - \frac{2}{n} \sum_{i=1}^{n} \big( y^{(i)} - \theta_0 - \theta_1 x^{(i)} \big)$$
#
# ## $$\frac{\partial MSE}{\partial \theta_1} = - \frac{2}{n} \sum_{i=1}^{n} \big( y^{(i)} - \theta_0 - \theta_1 x^{(i)} \big) \big( x^{(i)} \big)$$

# %% [markdown]
# ## MSE & Gradient Descent

# %%
#x values, y values, array of theta parametera(theta0 at index 0 and theta 1 at index 1)
def grad(x, y, thetas):
    n = y.size 
    
    theta0_slope = (-2/n) * sum(y - thetas[0] - thetas[1] * x)
    theta1_slope = (-2/n) * sum((y - thetas[0] - thetas[1] * x)*x)
    
    
    #return np.array([theta0_slope[0], theta1_slope[0]])
    #return np.append(arr=theta0_slope, values=theta1_slope)
    return np.concatenate((theta0_slope, theta1_slope), axis=0)

# %%
multiplier = 0.01
thetas = np.array([2.9,2.9])

#Collect data points for scatterplot
plot_vals = thetas.reshape(1,2)
mse_vals = mse(y_5, thetas[0] + thetas[1] * x_5)


for i in range(1000):
    thetas = thetas - multiplier * grad(x_5, y_5, thetas)
    
    # Append the new values to our numpy arrays
    plot_vals = np.concatenate((plot_vals, thetas.reshape(1, 2)), axis=0)
    mse_vals = np.append(arr=mse_vals, values=mse(y_5, thetas[0] + thetas[1]*x_5))

# Results
print('Min occurs at Theta 0:', thetas[0])
print('Min occurs at Theta 1:', thetas[1])
print('MSE is:', mse(y_5, thetas[0] + thetas[1]*x_5))
# Out:
# Min occurs at Theta 0: 0.8532230461743415
# Min occurs at Theta 1: 1.2214935332607393
# MSE is: [0.94797511]

# %%
# Plotting MSE
fig = plt.figure(figsize=[16, 12])
ax = fig.gca(projection='3d')

ax.set_xlabel('Theta 0', fontsize= 20)
ax.set_ylabel('Theta 1', fontsize= 20)
ax.set_zlabel('Cost - MSE', fontsize= 20)

ax.scatter(plot_vals[:,0], plot_vals[:,1], mse_vals, s=80, color='black')
ax.plot_surface(plot_t0, plot_t1, plot_cost, cmap=cm.rainbow, alpha=0.4)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
